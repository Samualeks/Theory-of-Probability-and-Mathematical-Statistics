# %% [markdown]
# Урок 4.
# 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
import pandas as pd
import numpy as np
from math import factorial as fl
import scipy.stats as st

# %% [markdown]
# 𝑀(𝑥)=(𝑎+𝑏)/2

# %%
MX = (200 + 800) / 2
MX
# Out:
# 500.0

# %% [markdown]
# 𝐷=〖(𝑏−𝑎)〗^2/12

# %%
DX = (800 - 200) ** 2 / 12
DX
# Out:
# 30000.0

# %% [markdown]
# 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %% [markdown]
# 𝐷(X)=〖(a+b)〗^2/12=0.2

# %% [markdown]
# a=0.5, из этой формулы выразим b, 0.2=〖(0.5+b)〗^2/12

# %%
a = 0.5
c = np.sqrt(2.4)
b = c + a
print(f'Правая граница равна {b}')
# Out:
# Правая граница равна 2.049193338482967

# %% [markdown]
# Теперь найдём среднее значение по формуле - 𝑀(𝑥)=(𝑎+𝑏)/2

# %%
M = (a +b)/2
M
# Out:
# 1.2745966692414834

# %% [markdown]
# 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-((x+2)**2) / 32))
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# а). M(X)

# %% [markdown]
# В общем виде плотность нормального распределения имеет вид: ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
MX = -2

# %% [markdown]
# б). D(X)

# %%
DX = 4**2
DX
# Out:
# 16

# %% [markdown]
# в). std(X) (среднее квадратичное отклонение)

# %%
stdX = 4

# %% [markdown]
# 4. Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %% [markdown]
# а). больше 182 см

# %%
hight = st.norm(loc=174, scale=8)
1 - hight.cdf(182)
# Out:
# 0.15865525393145707

# %% [markdown]
# б). больше 190 см

# %%
1 - hight.cdf(190)
# Out:
# 0.02275013194817921

# %% [markdown]
# в). от 166 см до 190 см

# %%
hight.cdf(190) - hight.cdf(166)
# Out:
# 0.8185946141203637

# %% [markdown]
# г). от 166 см до 182 см

# %%
hight.cdf(182) - hight.cdf(166)
# Out:
# 0.6826894921370859

# %% [markdown]
# д). от 158 см до 190 см

# %%
hight.cdf(190) - hight.cdf(158)
# Out:
# 0.9544997361036416

# %% [markdown]
# е). не выше 150 см или не ниже 190 см

# %%
hight.cdf(150) + (1 - hight.cdf(190))
# Out:
# 0.0241000299798093

# %% [markdown]
# ё). не выше 150 см или не ниже 198 см

# %%
hight.cdf(150) + (1 - hight.cdf(198))
# Out:
# 0.0026997960632601965

# %% [markdown]
# ж). ниже 166 см.

# %%
hight.cdf(166)
# Out:
# 0.15865525393145707

# %% [markdown]
# 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
(190 - 178) / np.sqrt(25)
# Out:
# 2.4
